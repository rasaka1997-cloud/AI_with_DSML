# %% [markdown]
# ## Try 6.2.1: Visualizing two numerical features in Python.

# %% [markdown]
# * **Click the double-right arrow to restart the kernel and run all cells.** *
#
# **Examine the code below.**
#
# * **Modify the code to produce a scatter plot of Total bill and Party size.**

# %%
# Import package
import seaborn as sns

# %%
# Load data
tips = sns.load_dataset('tips')
tips.columns = ['Total bill', 'Tip', 'Sex', 'Smoker', 'Day', 'Time', 'Party size']
tips
# Out:
#      Total bill   Tip     Sex Smoker   Day    Time  Party size
# 0         16.99  1.01  Female     No   Sun  Dinner           2
# 1         10.34  1.66    Male     No   Sun  Dinner           3
# 2         21.01  3.50    Male     No   Sun  Dinner           3
# 3         23.68  3.31    Male     No   Sun  Dinner           2
# 4         24.59  3.61  Female     No   Sun  Dinner           4
# ..          ...   ...     ...    ...   ...     ...         ...
# 239       29.03  5.92    Male     No   Sat  Dinner           3
# 240       27.18  2.00  Female    Yes   Sat  Dinner           2
# 241       22.67  2.00    Male    Yes   Sat  Dinner           2
# 242       17.82  1.75    Male     No   Sat  Dinner           2
# 243       18.78  3.00  Female     No  Thur  Dinner           2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Try 6.2.1: Visualizing two numwerical features in Python

# %% [markdown]
# * **Click the double-right arrow to restart the kernel and run all cells.**
# * **Examine the code below.**
#
# **Modify the code to produce a scatter plot of Total bill and Party size.**

# %%
# Create scatter plot
sns.scatterplot(data=tips, x='Total bill', y='Tip')
# Out:
# <Axes: xlabel='Total bill', ylabel='Tip'>

# %% [markdown]
# ## Try 6.2.2: Visualizing two categorical features in Python.

# %% [markdown]
# * **Click the double-right arrow to restart the kernel and run all cells.**
# * **Examine the code below.**
# * **Modify the code to place Time on the x axis and set Day as the hue feature.**

# %%
# Create grouped bar plot with Day as the categorical variable
# grouped according to Sex
sns.countplot(data=tips, x='Day', hue='Sex')
# Out:
# <Axes: xlabel='Day', ylabel='count'>

# %% [markdown]
# ## Try 6.2.3: Visualizing numerical and categorical features in Python.

# %% [markdown]
# * **Click the double-right arrow to restart the kernel and run all cells.**
# * **Examine the code below.**
# * **Modify the code to use time as the categorical feature and tip as the numerical feature.**

# %% [markdown]
# # Dicrete and continuous variables

# %%
# Import packages
import seaborn as sns

# %%
# Create strip plot for total bill grouped according to day
sns.stripplot(data=tips, x='Total bill', y='Day')
# Out:
# <Axes: xlabel='Total bill', ylabel='Day'>

# %%
# Create swarm plot for total bill grouped according to day
sns.swarmplot(data=tips, x='Day', y='Total bill')
# Out:
# <Axes: xlabel='Day', ylabel='Total bill'>

# %%
# Create kde plot for total bill grouped according to day
sns.kdeplot(data=tips, x='Total bill', hue='Day')
# Out:
# <Axes: xlabel='Total bill', ylabel='Density'>

# %%
# Create violin plot for total bill grouped according to day
sns.violinplot(data=tips, x="Day", y='Total bill')
# Out:
# <Axes: xlabel='Day', ylabel='Total bill'>

# %%
# Create grouped bar chart for total bill grouped according to day
sns.histplot(data=tips, x='Total bill', hue='Day', shrink=0.8, multiple="dodge")
# Out:
# <Axes: xlabel='Total bill', ylabel='Count'>

# %%
# Create stacked bar chart for total bill grouped according to day
sns.histplot(data=tips, x='Total bill', hue='Day', shrink=0.8, multiple="stack")
# Out:
# <Axes: xlabel='Total bill', ylabel='Count'>

# %% [markdown]
# ## Try 6.2.4: Visualizing multiple features in Python.

# %% [markdown]
# * **Click the double-right arrow to restart the kernel and run all cells.
# Examine the code below.**
# * **Modify the code to use Time as the categorical feature.**
# * **seaborn has several color palettes built in. Try some in the code below. Ex: "pastel", "dark", "viridis", "magma", "icefire", "Spectral".**

# %%
# Create scatter plot with color
sns.scatterplot(data=tips, x='Total bill', y='Tip', hue='Smoker', style='Smoker')
# Out:
# <Axes: xlabel='Total bill', ylabel='Tip'>

# %%
# Change color palette with palette
sns.scatterplot(
    data=tips,
    x='Total bill',
    y='Tip',
    hue='Smoker',
    style='Smoker',
    alpha=0.7,
    palette='colorblind',
)
# Out:
# <Axes: xlabel='Total bill', ylabel='Tip'>

# %%
# Faceted scatter plot
sns.relplot(
    data=tips,
    x="Total bill",
    y="Tip",
    col="Sex",
    hue="Sex",
    size="Party size",
    style="Time",
    height=3,
)

# %%
# Faceted count plot
sns.catplot(
    data=tips,
    x="Time",
    hue="Smoker",
    col="Day",
    col_wrap=2,
    kind="count",
    height=2.5,
    aspect=0.6,
)
